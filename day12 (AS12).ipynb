# %% [markdown]
# Plot the total sum of Transaction_Amount per Account_Type using a bar plot.
# Create a pie chart to show the percentage of transactions per Branch.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset from the file "banking_data.csv"
df = pd.read_csv("banking_data.csv")

# Plot 1: Total sum of Transaction_Amount per Account_Type (Bar plot)
transaction_sum_per_account_type = df.groupby('Account_Type')['Transaction_Amount'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Account_Type', y='Transaction_Amount', data=transaction_sum_per_account_type)
plt.title('Total Sum of Transaction_Amount per Account_Type')
plt.xlabel('Account Type')
plt.ylabel('Total Transaction Amount')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# Plot 2: Pie chart for the percentage of transactions per Branch
transaction_count_per_branch = df['Branch'].value_counts()

plt.figure(figsize=(8, 8))
transaction_count_per_branch.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')
plt.title('Percentage of Transactions per Branch')
plt.ylabel('')  # Remove the default y-axis label
plt.tight_layout()
plt.show()
