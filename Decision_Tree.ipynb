# %% [markdown]
# <a href="https://colab.research.google.com/github/snehith1438/2311cs020629/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-69f63aca-3c2a-46f1-87fa-8e66eb097e9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69f63aca-3c2a-46f1-87fa-8e66eb097e9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df = df.rename(columns={"Species":"Flowers_types"})

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#     Flowers_types
# 0          setosa
# 1          setosa
# 2          setosa
# 3          setosa
# 4          setosa
# ...

# %%
x=df.iloc[:,0:4]

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
y=df['Flowers_types']

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: Flowers_types, Length: 150, dtype: object

# %%
df['Flowers_types'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.Flowers_types.value_counts()
# Out:
# Flowers_types
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
from IPython import get_ipython
from IPython.display import display
# %%
import pandas as pd
from google.colab import files

# Upload the file and create the DataFrame 'df'
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

# %%
df

# %%
# Rename the column
df = df.rename(columns={"Species":"Flowers_types"})

# %%
df

# %%
# Select features
x=df.iloc[:,0:4]

# %%
x

# %%
# Select target variable
y=df['Flowers_types']

# %%
y

# %%
# Check unique values in 'Flowers_types' column
df['Flowers_types'].unique()

# %%
# Count occurrences of each flower type
df.Flowers_types.value_counts()

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#      <input type="file" id="files-1f06439a-976f-47e3-b13d-af33f46d8327" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f06439a-976f-47e3-b13d-af33f46d8327">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn import preprocessing # Import the preprocessing module from scikit-learn
label_encoder = preprocessing.LabelEncoder()
# Use the correct column name 'Flowers_types'
df['Flowers_types'] = label_encoder.fit_transform(df['Flowers_types'])

# %%
x=df.iloc[: 0:4]
